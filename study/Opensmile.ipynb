# %%
import opensmile
import pandas as pd
import numpy as np
from pandas import DataFrame
from glob import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.eGeMAPSv02,#FeatureSet　の後を変えれば他の音響特徴量セットに変えることができる
    feature_level=opensmile.FeatureLevel.Functionals,
)

# %%
#wavファイルがあるパス名を指定
y = smile.process_file('data/C001/C001_001/C001_001_IC01.wav')

# %%
pd.set_option('display.max_rows',None)
y.T
# Out:
# file                                           data/C001/C001_001/C001_001_IC01.wav
# start                                                                        0 days
# end                                                       0 days 00:31:24.716187500
# F0semitoneFrom27.5Hz_sma3nz_amean                                         40.062195
# F0semitoneFrom27.5Hz_sma3nz_stddevNorm                                     0.160153
# F0semitoneFrom27.5Hz_sma3nz_percentile20.0                                34.674168
# F0semitoneFrom27.5Hz_sma3nz_percentile50.0                                38.841885
# F0semitoneFrom27.5Hz_sma3nz_percentile80.0                                45.134460
# F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2                                  10.460293
# F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope                              219.302872
# F0semitoneFrom27.5Hz_sma3nz_stddevRisingSlope                            331.919098
# F0semitoneFrom27.5Hz_sma3nz_meanFallingSlope                             116.073257
# F0semitoneFrom27.5Hz_sma3nz_stddevFallingSlope                           202.781723
# loudness_sma3_amean                                                        0.477722
# loudness_sma3_stddevNorm                                                   1.016622
# loudness_sma3_percentile20.0                                               0.184246
# loudness_sma3_percentile50.0                                               0.307984
# loudness_sma3_percentile80.0                                               0.653982
# loudness_sma3_pctlrange0-2                                                 0.469736
# loudness_sma3_meanRisingSlope                                              9.986142
# loudness_sma3_stddevRisingSlope                                            9.126328
# loudness_sma3_meanFallingSlope                                             7.908751
# loudness_sma3_stddevFallingSlope                                           7.459353
# spectralFlux_sma3_amean                                                    0.162261
# spectralFlux_sma3_stddevNorm                                               2.190778
# mfcc1_sma3_amean                                                          16.984842
# mfcc1_sma3_stddevNorm                                                      0.509246
# mfcc2_sma3_amean                                                         -20.142872
# mfcc2_sma3_stddevNorm                                                     -0.565561
# mfcc3_sma3_amean                                                          -9.149968
# mfcc3_sma3_stddevNorm                                                     -1.352730
# mfcc4_sma3_amean                                                         -19.849077
# mfcc4_sma3_stddevNorm                                                     -0.802938
# jitterLocal_sma3nz_amean                                                   0.030966
# jitterLocal_sma3nz_stddevNorm                                              1.624460
# shimmerLocaldB_sma3nz_amean                                                1.219560
# shimmerLocaldB_sma3nz_stddevNorm                                           0.583173
# HNRdBACF_sma3nz_amean                                                      5.332201
# HNRdBACF_sma3nz_stddevNorm                                                 0.925545
# logRelF0-H1-H2_sma3nz_amean                                                2.516949
# logRelF0-H1-H2_sma3nz_stddevNorm                                           4.226245
# logRelF0-H1-A3_sma3nz_amean                                               15.479419
# logRelF0-H1-A3_sma3nz_stddevNorm                                           0.648163
# F1frequency_sma3nz_amean                                                 826.693665
# F1frequency_sma3nz_stddevNorm                                              0.303054
# F1bandwidth_sma3nz_amean                                                1361.076050
# F1bandwidth_sma3nz_stddevNorm                                              0.202238
# F1amplitudeLogRelF0_sma3nz_amean                                         -77.820724
# F1amplitudeLogRelF0_sma3nz_stddevNorm                                     -1.230447
# F2frequency_sma3nz_amean                                                1765.014526
# F2frequency_sma3nz_stddevNorm                                              0.137794
# F2bandwidth_sma3nz_amean                                                1186.654541
# F2bandwidth_sma3nz_stddevNorm                                              0.261044
# F2amplitudeLogRelF0_sma3nz_amean                                         -70.636551
# F2amplitudeLogRelF0_sma3nz_stddevNorm                                     -1.256448
# F3frequency_sma3nz_amean                                                2760.968506
# F3frequency_sma3nz_stddevNorm                                              0.090187
# F3bandwidth_sma3nz_amean                                                 982.474304
# F3bandwidth_sma3nz_stddevNorm                                              0.339510
# F3amplitudeLogRelF0_sma3nz_amean                                         -74.783684
# F3amplitudeLogRelF0_sma3nz_stddevNorm                                     -1.143315
# alphaRatioV_sma3nz_amean                                                  -5.046000
# alphaRatioV_sma3nz_stddevNorm                                             -1.109160
# hammarbergIndexV_sma3nz_amean                                             16.852585
# hammarbergIndexV_sma3nz_stddevNorm                                         0.487298
# slopeV0-500_sma3nz_amean                                                   0.070921
# slopeV0-500_sma3nz_stddevNorm                                              0.365386
# slopeV500-1500_sma3nz_amean                                               -0.006361
# slopeV500-1500_sma3nz_stddevNorm                                          -2.457454
# spectralFluxV_sma3nz_amean                                                 0.202813
# spectralFluxV_sma3nz_stddevNorm                                            2.002995
# mfcc1V_sma3nz_amean                                                       18.736103
# mfcc1V_sma3nz_stddevNorm                                                   0.431812
# mfcc2V_sma3nz_amean                                                      -22.132912
# mfcc2V_sma3nz_stddevNorm                                                  -0.519943
# mfcc3V_sma3nz_amean                                                      -10.567513
# mfcc3V_sma3nz_stddevNorm                                                  -1.224310
# mfcc4V_sma3nz_amean                                                      -24.834536
# mfcc4V_sma3nz_stddevNorm                                                  -0.630078
# alphaRatioUV_sma3nz_amean                                                 -1.807253
# hammarbergIndexUV_sma3nz_amean                                            11.350392
# slopeUV0-500_sma3nz_amean                                                  0.051348
# slopeUV500-1500_sma3nz_amean                                               0.004208
# spectralFluxUV_sma3nz_amean                                                0.082994
# loudnessPeaksPerSec                                                        0.887144
# VoicedSegmentsPerSec                                                       0.530710
# MeanVoicedSegmentLengthSec                                                 0.229830
# StddevVoicedSegmentLengthSec                                               0.294057
# MeanUnvoicedSegmentLength                                                  0.090730
# StddevUnvoicedSegmentLength                                                0.094331
# equivalentSoundLevel_dBp                                                 -25.283670
